# %%
# importing pandas library

import pandas as pd

# %%
# read csv file
df=pd.read_csv("data/accounts.csv")

# %%
# to confirom data has read successfully, lets retun first few rows
df.head()
# Out:
#    acct_id dsply_nm type acct_stat acct_rptng_crncy  prior_sar_count  \
# 0        0      C_0    I         A              USD            False
# 1        1      C_1    I         A              USD            False
# 2        2      C_2    I         A              USD            False
# 3        3      C_3    I         A              USD            False
# 4        4      C_4    I         A              USD            False
#
#    branch_id               open_dt              close_dt  initial_deposit  \
# 0          1  2021-01-01T00:00:00Z  4758-11-29T00:00:00Z         92221.09
# 1          1  2021-01-01T00:00:00Z  4758-11-29T00:00:00Z         87897.72
# 2          1  2021-01-01T00:00:00Z  4758-11-29T00:00:00Z         71028.58
# 3          1  2021-01-01T00:00:00Z  4758-11-29T00:00:00Z         62945.84
# 4          1  2021-01-01T00:00:00Z  4758-11-29T00:00:00Z         75563.74
#
#    ...                    street_addr         city state country    zip  \
# ...

# %%
# selecting a single column from above dataset
df['acct_id']
# Out:
# 0          0
# 1          1
# 2          2
# 3          3
# 4          4
#         ...
# 1441    1441
# 1442    1442
# 1443    1443
# 1444    1444
# 1445    1445
# Name: acct_id, Length: 1446, dtype: int64

# %%
# selecting a few columns from above dataset
df[['acct_id','dsply_nm','acct_stat']]
# Out:
#       acct_id dsply_nm acct_stat
# 0           0      C_0         A
# 1           1      C_1         A
# 2           2      C_2         A
# 3           3      C_3         A
# 4           4      C_4         A
# ...       ...      ...       ...
# 1441     1441   C_1441         A
# 1442     1442   C_1442         A
# 1443     1443   C_1443         A
# 1444     1444   C_1444         A
# 1445     1445   C_1445         A
#
# [1446 rows x 3 columns]

# %%
# select sells in a range (return 10-15 rows)
df[10:15]
# Out:
#     acct_id dsply_nm type acct_stat acct_rptng_crncy  prior_sar_count  \
# 10       10     C_10    I         A              USD            False
# 11       11     C_11    I         A              USD            False
# 12       12     C_12    I         A              USD            False
# 13       13     C_13    I         A              USD            False
# 14       14     C_14    I         A              USD             True
#
#     branch_id               open_dt              close_dt  initial_deposit  \
# 10          1  2021-01-01T00:00:00Z  4758-11-29T00:00:00Z         95405.64
# 11          1  2021-01-01T00:00:00Z  4758-11-29T00:00:00Z         75234.34
# 12          1  2021-01-01T00:00:00Z  4758-11-29T00:00:00Z         64091.89
# 13          1  2021-01-01T00:00:00Z  4758-11-29T00:00:00Z         87790.21
# 14          1  2021-01-01T00:00:00Z  4758-11-29T00:00:00Z         80918.45
#
#     ...                   street_addr                  city state country  \
# ...

# %%
# selecting rows by their positions (ex: select 5,8,20 rows).
df.iloc[[5,8,20]]
# Out:
#     acct_id dsply_nm type acct_stat acct_rptng_crncy  prior_sar_count  \
# 5         5      C_5    I         A              USD            False
# 8         8      C_8    I         A              USD            False
# 20       20     C_20    I         A              USD            False
#
#     branch_id               open_dt              close_dt  initial_deposit  \
# 5           1  2021-01-01T00:00:00Z  4758-11-29T00:00:00Z         70246.71
# 8           1  2021-01-01T00:00:00Z  4758-11-29T00:00:00Z         73829.85
# 20          1  2021-01-01T00:00:00Z  4758-11-29T00:00:00Z         65507.38
#
#     ...                   street_addr                    city state country  \
# 5   ...           13991 Davis Village  North Catherineborough    VT      US
# 8   ...            5945 Jennifer Loaf               Pooleland    PA      US
# 20  ...  3751 Rachel Canyon Suite 408            East Clayton    SC      US
#
#       zip gender  birth_date          ssn         lon        lat
# ...

# %%
# we can use iloc to use slicing using square brackets.
df.iloc[10:15]
# Out:
#     acct_id dsply_nm type acct_stat acct_rptng_crncy  prior_sar_count  \
# 10       10     C_10    I         A              USD            False
# 11       11     C_11    I         A              USD            False
# 12       12     C_12    I         A              USD            False
# 13       13     C_13    I         A              USD            False
# 14       14     C_14    I         A              USD             True
#
#     branch_id               open_dt              close_dt  initial_deposit  \
# 10          1  2021-01-01T00:00:00Z  4758-11-29T00:00:00Z         95405.64
# 11          1  2021-01-01T00:00:00Z  4758-11-29T00:00:00Z         75234.34
# 12          1  2021-01-01T00:00:00Z  4758-11-29T00:00:00Z         64091.89
# 13          1  2021-01-01T00:00:00Z  4758-11-29T00:00:00Z         87790.21
# 14          1  2021-01-01T00:00:00Z  4758-11-29T00:00:00Z         80918.45
#
#     ...                   street_addr                  city state country  \
# ...

# %%
# Select by condition (ex: select accounts where account type is individual)
df[df['type']=='I']
# Out:
#       acct_id dsply_nm type acct_stat acct_rptng_crncy  prior_sar_count  \
# 0           0      C_0    I         A              USD            False
# 1           1      C_1    I         A              USD            False
# 2           2      C_2    I         A              USD            False
# 3           3      C_3    I         A              USD            False
# 4           4      C_4    I         A              USD            False
# ...       ...      ...  ...       ...              ...              ...
# 1195     1195   C_1195    I         A              USD            False
# 1196     1196   C_1196    I         A              USD            False
# 1197     1197   C_1197    I         A              USD            False
# 1198     1198   C_1198    I         A              USD            False
# 1199     1199   C_1199    I         A              USD            False
#
#       branch_id               open_dt              close_dt  initial_deposit  \
# ...

# %%
# Show now of rows x columns
df.shape
# Out:
# (1446, 24)

# %%
# show data columns
df.columns
# Out:
# Index(['acct_id', 'dsply_nm', 'type', 'acct_stat', 'acct_rptng_crncy',
#        'prior_sar_count', 'branch_id', 'open_dt', 'close_dt',
#        'initial_deposit', 'tx_behavior_id', 'bank_id', 'first_name',
#        'last_name', 'street_addr', 'city', 'state', 'country', 'zip', 'gender',
#        'birth_date', 'ssn', 'lon', 'lat'],
#       dtype='object')

# %%
# show 1st 5 rows
df.head(5)
# Out:
#    acct_id dsply_nm type acct_stat acct_rptng_crncy  prior_sar_count  \
# 0        0      C_0    I         A              USD            False
# 1        1      C_1    I         A              USD            False
# 2        2      C_2    I         A              USD            False
# 3        3      C_3    I         A              USD            False
# 4        4      C_4    I         A              USD            False
#
#    branch_id               open_dt              close_dt  initial_deposit  \
# 0          1  2021-01-01T00:00:00Z  4758-11-29T00:00:00Z         92221.09
# 1          1  2021-01-01T00:00:00Z  4758-11-29T00:00:00Z         87897.72
# 2          1  2021-01-01T00:00:00Z  4758-11-29T00:00:00Z         71028.58
# 3          1  2021-01-01T00:00:00Z  4758-11-29T00:00:00Z         62945.84
# 4          1  2021-01-01T00:00:00Z  4758-11-29T00:00:00Z         75563.74
#
#    ...                    street_addr         city state country    zip  \
# ...

# %%
# select rows based on condition (or we can use same previous way or loc utility)
# and-> &
# or-> |
# not-> !
df[(df.acct_stat=='A') & (df.type=='U')]
# Out:
#       acct_id dsply_nm type acct_stat acct_rptng_crncy  prior_sar_count  \
# 10       1427   C_1427    U         A              USD            False
# 52       1438   C_1438    U         A              USD            False
# 63       1406   C_1406    U         A              USD            False
# 85       1414   C_1414    U         A              USD            False
# 100      1402   C_1402    U         A              USD            False
# 134      1401   C_1401    U         A              USD            False
# 167      1411   C_1411    U         A              USD            False
# 194      1421   C_1421    U         A              USD            False
# 214      1412   C_1412    U         A              USD            False
# 235      1437   C_1437    U         A              USD            False
# 246      1435   C_1435    U         A              USD            False
# 259      1409   C_1409    U         A              USD            False
# ...

# %%
# Dataframes with sepcific colum set
select_columns =['acct_id','type','acct_stat']
df[select_columns]
# Out:
#       acct_id type acct_stat
# 0           0    I         A
# 1           1    I         A
# 2           2    I         A
# 3           3    I         A
# 4           4    I         A
# ...       ...  ...       ...
# 1441     1441    U         A
# 1442     1442    U         A
# 1443     1443    U         A
# 1444     1444    U         A
# 1445     1445    U         A
#
# [1446 rows x 3 columns]

# %%
# check the data types of each column
df.dtypes
# Out:
# acct_id               int64
# dsply_nm             object
# type                 object
# acct_stat            object
# acct_rptng_crncy     object
# prior_sar_count        bool
# branch_id             int64
# open_dt              object
# close_dt             object
# initial_deposit     float64
# tx_behavior_id        int64
# bank_id              object
# first_name           object
# last_name            object
# street_addr          object
# city                 object
# state                object
# country              object
# zip                   int64
# gender               object
# birth_date           object
# ssn                  object
# lon                 float64
# lat                 float64
# dtype: object

# %%
# check for the null values (missing values).If there is any missing value we can replace with mean.
df.isna().sum()
# Out:
# acct_id             0
# dsply_nm            0
# type                0
# acct_stat           0
# acct_rptng_crncy    0
# prior_sar_count     0
# branch_id           0
# open_dt             0
# close_dt            0
# initial_deposit     0
# tx_behavior_id      0
# bank_id             0
# first_name          0
# last_name           0
# street_addr         0
# city                0
# state               0
# country             0
# zip                 0
# gender              0
# birth_date          0
# ssn                 0
# lon                 0
# lat                 0
# dtype: int64

# %%
# show frequency in each catgorty ( show number of account type catagories based on type)
df.type.value_counts()
# Out:
# I    1200
# M     200
# U      46
# Name: type, dtype: int64

# %%
# sort accounts by city
select_columns = ['acct_id','city','initial_deposit']
df.sort_values(by=['city'])[select_columns]
# Out:
#       acct_id         city  initial_deposit
# 601       601    Aaronport         94185.90
# 485       485    Aaronview         96787.74
# 366       366  Abigailfort         85906.58
# 131       131    Adamburgh         96848.46
# 292       292    Adamshire         92042.42
# ...       ...          ...              ...
# 1239     1239   Wrightport         62014.52
# 537       537  Wrightshire         65794.57
# 78         78   Wrightview         96169.05
# 1059     1059   Youngburgh         75444.95
# 557       557   Zavalaberg         52892.86
#
# [1446 rows x 3 columns]

# %%
# sort accounts by city & intial deposit by desending
select_columns = ['acct_id','city','initial_deposit']
df.sort_values(by=['city','initial_deposit'],ascending=[True,False])[select_columns]
# Out:
#       acct_id         city  initial_deposit
# 601       601    Aaronport         94185.90
# 485       485    Aaronview         96787.74
# 366       366  Abigailfort         85906.58
# 131       131    Adamburgh         96848.46
# 292       292    Adamshire         92042.42
# ...       ...          ...              ...
# 1239     1239   Wrightport         62014.52
# 537       537  Wrightshire         65794.57
# 78         78   Wrightview         96169.05
# 1059     1059   Youngburgh         75444.95
# 557       557   Zavalaberg         52892.86
#
# [1446 rows x 3 columns]

# %%
### INPLACE DATA FRAME MODIFICATION (otherwise our original data frame wont change)

df.sort_values(by=['city'],ascending=[True], inplace=True)
# now our index is not orderd.
df.head()
# Out:
#      acct_id dsply_nm type acct_stat acct_rptng_crncy  prior_sar_count  \
# 601      601    C_601    I         A              USD            False
# 485      485    C_485    I         A              USD            False
# 366      366    C_366    I         A              USD            False
# 131      131    C_131    I         A              USD            False
# 292      292    C_292    I         A              USD            False
#
#      branch_id               open_dt              close_dt  initial_deposit  \
# 601          1  2021-01-01T00:00:00Z  4758-11-29T00:00:00Z         94185.90
# 485          1  2021-01-01T00:00:00Z  4758-11-29T00:00:00Z         96787.74
# 366          1  2021-01-01T00:00:00Z  4758-11-29T00:00:00Z         85906.58
# 131          1  2021-01-01T00:00:00Z  4758-11-29T00:00:00Z         96848.46
# 292          1  2021-01-01T00:00:00Z  4758-11-29T00:00:00Z         92042.42
#
#      ...                  street_addr         city state country    zip  \
# ...

# %%
# reorderd index
df.reset_index(inplace=True,drop=True)
df.head()
# Out:
#    acct_id dsply_nm type acct_stat acct_rptng_crncy  prior_sar_count  \
# 0      601    C_601    I         A              USD            False
# 1      485    C_485    I         A              USD            False
# 2      366    C_366    I         A              USD            False
# 3      131    C_131    I         A              USD            False
# 4      292    C_292    I         A              USD            False
#
#    branch_id               open_dt              close_dt  initial_deposit  \
# 0          1  2021-01-01T00:00:00Z  4758-11-29T00:00:00Z         94185.90
# 1          1  2021-01-01T00:00:00Z  4758-11-29T00:00:00Z         96787.74
# 2          1  2021-01-01T00:00:00Z  4758-11-29T00:00:00Z         85906.58
# 3          1  2021-01-01T00:00:00Z  4758-11-29T00:00:00Z         96848.46
# 4          1  2021-01-01T00:00:00Z  4758-11-29T00:00:00Z         92042.42
#
#    ...                  street_addr         city state country    zip  gender  \
# ...

# %%
# group by column
d=df.groupby(['state','city'])
d.first()
# Out:
#                          acct_id dsply_nm type acct_stat acct_rptng_crncy  \
# state city
# AK    Burtonshire           1192   C_1192    I         A              USD
#       Campbellfurt           151    C_151    I         A              USD
#       Candiceland            336    C_336    I         A              USD
#       Christophertown        523    C_523    I         A              USD
#       East Kyletown         1393   C_1393    M         A              USD
# ...                          ...      ...  ...       ...              ...
# WY    South Kristin         1182   C_1182    I         A              USD
#       South Patrick         1207   C_1207    M         A              USD
#       Stephanieland           24     C_24    I         A              USD
#       Stewartborough        1294   C_1294    M         A              USD
#       West Nicholasview      446    C_446    I         A              USD
#
# ...
